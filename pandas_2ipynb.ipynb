# %% [markdown]
# <a href="https://colab.research.google.com/github/lenaphamthi/bai_tap_pandas/blob/main/pandas_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ho_va_ten = pd.Series(["Phạm Thị Lê Na","Phạm Trang","Phan Ngọc","Nguyễn Nga","Chu Dương ","Trần Mai","Nguyễn Thủy","Ngô Đạt","Vũ KháKhánh","Phạm Tưởng"])
ngay_sinh = pd.Series(["25/04/2003","21/03/1997","01/08/2003","05/12/2003","01/06/2003","15/10/2003","21/04/1999","10/10/2003","02/09/2003","15/09/1969"])
tien_cong_gio  = pd.Series([100,4000,6000,300,8000,70,300,20,500,9000])
so_gio_cong = pd.Series([1,2,4,6,8,7,9,3,10,4])
thuc_linh = pd.Series([])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.DataFrame({"Họ và tên":ho_va_ten,"Ngày sinh":ngay_sinh,"Tiền công/giờ":tien_cong_gio,"Số giờ công": so_gio_cong,"Thực lĩnh":thuc_linh})
df["Thực lĩnh"]= df["Số giờ công"]* df["Tiền công/giờ"]
df
# Out:
#         Họ và tên   Ngày sinh  Tiền công/giờ  Số giờ công  Thực lĩnh
# 0  Phạm Thị Lê Na  25/04/2003            100            1        100
# 1      Phạm Trang  21/03/1997           4000            2       8000
# 2       Phan Ngọc  01/08/2003           6000            4      24000
# 3      Nguyễn Nga  05/12/2003            300            6       1800
# 4      Chu Dương   01/06/2003           8000            8      64000
# 5        Trần Mai  15/10/2003             70            7        490
# 6     Nguyễn Thủy  21/04/1999            300            9       2700
# 7         Ngô Đạt  10/10/2003             20            3         60
# 8     Vũ KháKhánh  02/09/2003            500           10       5000
# 9      Phạm Tưởng  15/09/1969           9000            4      36000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ho_va_ten = ["Phạm Thị Lê Na","Phạm Trang","Phan Ngọc","Nguyễn Nga","Chu Dương ","Trần Mai","Nguyễn Thủy","Ngô Đạt","Vũ Khánh","Phạm Tưởng"]
tuoi =[18,25,19,16,18,17,18,19,45,50]
gioi_tinh = ["nữ","nữ","nữ","nữ","nữ","nam","nữ","nam","nam","nam"]
df1 = pd.DataFrame(np.array([ho_va_ten,tuoi,gioi_tinh]).T,columns =["Họ và tên","Tuổi","Giới tính"])
df1
# Out:
#         Họ và tên Tuổi Giới tính
# 0  Phạm Thị Lê Na   18        nữ
# 1      Phạm Trang   25        nữ
# 2       Phan Ngọc   19        nữ
# 3      Nguyễn Nga   16        nữ
# 4      Chu Dương    18        nữ
# 5        Trần Mai   17       nam
# 6     Nguyễn Thủy   18        nữ
# 7         Ngô Đạt   19       nam
# 8        Vũ Khánh   45       nam
# 9      Phạm Tưởng   50       nam

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ho_va_ten = pd.Series(["Phạm Thị Lê Na","Phạm Trang","Phan Ngọc","Nguyễn Nga","Chu Dương ","Trần Mai","Nguyễn Thủy","Ngô Đạt","Vũ Khánh","Phạm Tưởng"])
tuoi = pd.Series([18,25,19,16,18,17,18,19,45,50])
gioi_tinh = pd.Series(["nữ","nữ","nữ","nữ","nữ","nam","nữ","nam","nam","nam"])
df2= pd.DataFrame({"Họ và tên": ho_va_ten,"Tuổi": tuoi,"Giới tính":gioi_tinh})
df2
# Out:
#         Họ và tên  Tuổi Giới tính
# 0  Phạm Thị Lê Na    18        nữ
# 1      Phạm Trang    25        nữ
# 2       Phan Ngọc    19        nữ
# 3      Nguyễn Nga    16        nữ
# 4      Chu Dương     18        nữ
# 5        Trần Mai    17       nam
# 6     Nguyễn Thủy    18        nữ
# 7         Ngô Đạt    19       nam
# 8        Vũ Khánh    45       nam
# 9      Phạm Tưởng    50       nam

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df3 = pd.DataFrame([{"Họ và tên":"Phạm Thị Lê Na","Tuổi":18,"Giới tính":"nữ"},{"Họ và tên":"Phạm Trang","Tuổi":25 ,"Giới tính":"nữ"},{"Họ và tên":"Phan Ngọc","Tuổi":18,"Giới tính":"nữ"},{"Họ và tên":"Nguyễn Nga","Tuổi":18,"Giới tính":"nữ"},{"Họ và tên":"Chu Dương","Tuổi":18,"Giới tính":"nữ"},{"Họ và tên":"Trần Mai","Tuổi":18,"Giới tính":"nữ"},{"Họ và tên":"Nguyễn Thủy","Tuổi":45,"Giới tính":"nữ"},{"Họ và tên":"Ngô Đạt","Tuổi":18,"Giới tính":"nam "},{"Họ và tên":"Vũ Khánh","Tuổi":18,"Giới tính":"nam"},{"Họ và tên":"Phạm Tưởng","Tuổi":50 ,"Giới tính":"nam"}])
df3
# Out:
#         Họ và tên  Tuổi Giới tính
# 0  Phạm Thị Lê Na    18        nữ
# 1      Phạm Trang    25        nữ
# 2       Phan Ngọc    18        nữ
# 3      Nguyễn Nga    18        nữ
# 4       Chu Dương    18        nữ
# 5        Trần Mai    18        nữ
# 6     Nguyễn Thủy    45        nữ
# 7         Ngô Đạt    18      nam
# 8        Vũ Khánh    18       nam
# 9      Phạm Tưởng    50       nam

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df4 = pd.DataFrame(zip(ho_va_ten, tuoi, gioi_tinh), columns = ["Họ và tên", "Tuổi", "Giới tính"])
df4
# Out:
#         Họ và tên  Tuổi Giới tính
# 0  Phạm Thị Lê Na    18        nữ
# 1      Phạm Trang    25        nữ
# 2       Phan Ngọc    19        nữ
# 3      Nguyễn Nga    16        nữ
# 4      Chu Dương     18        nữ
# 5        Trần Mai    17       nam
# 6     Nguyễn Thủy    18        nữ
# 7         Ngô Đạt    19       nam
# 8        Vũ Khánh    45       nam
# 9      Phạm Tưởng    50       nam
